# %%
 # Importing Required Libraries
import pandas as pd
import numpy as np
import re
from nltk.tokenize import RegexpTokenizer, word_tokenize
 
import nltk.corpus
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Welcome\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#importing Phone Review Excel Dataset. 
Data = pd.read_csv("data_.csv")
Data
# Out:
#                                           Product Name Brand Name   Price  \
# 0    "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 1    "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 2    "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 3    "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 4    "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# ..                                                 ...        ...     ...
# 194  [XMAS DEAL] Jethro [SC118] Simple Unlocked Qua...     Jethro   59.99
# 195  [XMAS DEAL] Jethro [SC118] Simple Unlocked Qua...     Jethro   59.99
# 196  [XMAS DEAL] Jethro [SC118] Simple Unlocked Qua...     Jethro   59.99
# 197  [XMAS DEAL] Jethro [SC118] Simple Unlocked Qua...     Jethro   59.99
# 198  [XMAS DEAL] Jethro [SC118] Simple Unlocked Qua...     Jethro   59.99
#
#      Rating                                            Reviews  Review Votes
# ...

# %%
# Droping All columns except Rating and Reviews. 
Data.drop(columns=["Product Name", "Brand Name", "Price", "Review Votes"], inplace = True)
Data
# Out:
#      Rating                                            Reviews
# 0         5  I feel so LUCKY to have found this used (phone...
# 1         4  nice phone, nice up grade from my pantach revu...
# 2         5                                       Very pleased
# 3         4  It works good but it goes slow sometimes but i...
# 4         4  Great phone to replace my lost phone. The only...
# ..      ...                                                ...
# 194       4  This is a great, simple phone which is getting...
# 195       2  My Granny couldn't use the phone because she w...
# 196       2  Not good sound, not easily used by senior, end...
# 197       5  really surprised by this phone, with fm radio ...
# 198       5           Nice big numbers everywhere! Simple too!
#
# [199 rows x 2 columns]

# %%
# Convert your data frame to array - only use Reviews column
corpus = np.array(Data["Reviews"])
corpus
# Out:
# array(["I feel so LUCKY to have found this used (phone to us & not used hard at all), phone on line from someone who upgraded and sold this one. My Son liked his old one that finally fell apart after 2.5+ years and didn't want an upgrade!! Thank you Seller, we really appreciate it & your honesty re: said used phone.I recommend this seller very highly & would but from them again!!",
#        'nice phone, nice up grade from my pantach revue. Very clean set up and easy set up. never had an android phone but they are fantastic to say the least. perfect size for surfing and social media. great phone samsung',
#        'Very pleased',
#        'It works good but it goes slow sometimes but its a very good phone I love it',
#        'Great phone to replace my lost phone. The only thing is the volume up button does not work, but I can still go into settings to adjust. Other than that, it does the job until I am eligible to upgrade my phone again.Thaanks!',
# ...

# %%
# Converting from multi-dimensional array to 1 dimension

corpus = corpus.ravel()
curpus[0]
# Out:
# "I feel so LUCKY to have found this used (phone to us & not used hard at all), phone on line from someone who upgraded and sold this one. My Son liked his old one that finally fell apart after 2.5+ years and didn't want an upgrade!! Thank you Seller, we really appreciate it & your honesty re: said used phone.I recommend this seller very highly & would but from them again!!"

# %%
# Create a normalize_docuement function to lowercase, remove white spaces, remove stop words, remove special characters, etc. Hint! First create a WordPunctTokenizer variable

# %%
sentence=str(curpus[0])
sentence = sentence.lower()
cleanr = re.compile('[&:()+!!.,]')
cleantext = re.sub(cleanr, '', sentence)
rem_num = re.sub('[0-9]+', '', cleantext)
tokenizer = RegexpTokenizer(r'\w+')
tokens = tokenizer.tokenize(rem_num) 
filtered_words = [w for w in tokens if len(w) > 2 if not w in stopwords.words('english')]
#filtered_words

# %%
 def normalize_docuement(txt):
        
    txt=str(txt) # Coverting into string dtype
    
    txt = txt.lower() # Converting into lowercase
    
    # removing special_characters
    special_characters = re.compile('<.*?:>')
    cleanedtext = re.sub(special_characters, '', txt)
    
    
    # Removing Numbers
    removedNum = re.sub('[0-9]+', '', cleanedtext)
    
    # Removing stop words
    WordPunctTokenizer = RegexpTokenizer(r'\w+')
    tokens = WordPunctTokenizer.tokenize(removedNum)  
    filtered_words = [w for w in tokens if len(w) > 2 if not w in stopwords.words('english')]
    
    return " ".join(filtered_words)


Data['cleanText']=Data['Reviews'].map(lambda s:normalize_docuement(s))

# %%
Data
# Out:
#      Rating                                            Reviews  \
# 0         5  I feel so LUCKY to have found this used (phone...
# 1         4  nice phone, nice up grade from my pantach revu...
# 2         5                                       Very pleased
# 3         4  It works good but it goes slow sometimes but i...
# 4         4  Great phone to replace my lost phone. The only...
# ..      ...                                                ...
# 194       4  This is a great, simple phone which is getting...
# 195       2  My Granny couldn't use the phone because she w...
# 196       2  Not good sound, not easily used by senior, end...
# 197       5  really surprised by this phone, with fm radio ...
# 198       5           Nice big numbers everywhere! Simple too!
#
#                                              cleanText
# 0    feel lucky found used phone used hard phone li...
# 1    nice phone nice grade pantach revue clean set ...
# ...
